# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
df.drop('sales',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 1.0+ MB

# %%
df.shape
# Out:
# (14999, 9)

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
df['salary']=df['salary'].map({'low':0,'medium':1,'high':2})

# %%
df['Work_accident'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['promotion_last_5years'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # EDA on categorical Column

# %%
sns.countplot(x='left',data=df)
plt.show()

# %% [markdown]
# We have Imbalance Dataset

# %%
sns.countplot(x='salary',data=df)
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %% [markdown]
# Low Salary have high chance to leave

# %%
sns.catplot(x='left',col='salary',kind='count',data=df)

# %%
sns.countplot(x='promotion_last_5years',data=df)
# Out:
# <Axes: xlabel='promotion_last_5years', ylabel='count'>

# %%
sns.catplot(x='left',col='promotion_last_5years',kind='count',data=df)

# %%
sns.countplot(x='Work_accident',data=df)
# Out:
# <Axes: xlabel='Work_accident', ylabel='count'>

# %%
sns.catplot(x='left',col='Work_accident',kind='count',data=df)

# %%
sns.distplot(df['satisfaction_level'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13552\667929916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['satisfaction_level'])
# <Axes: xlabel='satisfaction_level', ylabel='Density'>

# %%
sns.boxplot(x='left',y='satisfaction_level',data=df)
# Out:
# <Axes: xlabel='left', ylabel='satisfaction_level'>

# %%
sns.distplot(df['number_project'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13552\487619780.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['number_project'])
# <Axes: xlabel='number_project', ylabel='Density'>

# %%
sns.boxplot(x='left',y='number_project',data=df)
# Out:
# <Axes: xlabel='left', ylabel='number_project'>

# %%
sns.distplot(df['last_evaluation'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13552\3558093561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['last_evaluation'])
# <Axes: xlabel='last_evaluation', ylabel='Density'>

# %%
sns.boxplot(x='left',y='last_evaluation',data=df)
# Out:
# <Axes: xlabel='left', ylabel='last_evaluation'>

# %%
sns.distplot(df['average_montly_hours'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13552\2210345607.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['average_montly_hours'])
# <Axes: xlabel='average_montly_hours', ylabel='Density'>

# %%
sns.boxplot(x='left',y='average_montly_hours',data=df)
# Out:
# <Axes: xlabel='left', ylabel='average_montly_hours'>

# %%
sns.distplot(df['time_spend_company'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13552\3888117077.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['time_spend_company'])
# <Axes: xlabel='time_spend_company', ylabel='Density'>

# %%
sns.boxplot(x='left',y='time_spend_company',data=df)
# Out:
# <Axes: xlabel='left', ylabel='time_spend_company'>

# %%
cor_mat=df.corr()
fig=plt.figure(figsize=(15,7))
sns.heatmap(cor_mat,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# # Feature Engineering

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# salary                   0
# dtype: int64

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years        salary
# count           14999.000000  14999.000000
# mean                0.021268      0.594706
# std                 0.144281      0.637183
# min                 0.000000      0.000000
# 25%                 0.000000      0.000000
# 50%                 0.000000      1.000000
# 75%                 0.000000      1.000000
# max                 1.000000      2.000000

# %%
X=df.drop(labels='left',axis=1)
y=df['left']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3, random_state=42)

# %%
len(X_train),len(X_test)
# Out:
# (10499, 4500)

# %% [markdown]
# # Model Selection

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
model_parm={
    'RandomForestClassifier':{
        'model':RandomForestClassifier(),
        'param':{
            'n_estimators':[10,50,100,130],
            'criterion':['gini','entropy'],
            'max_depth':range(2,4,1),
            'max_features':['sqrt','log2']
        }
    },
    'XGBClassifier':{
        'model':XGBClassifier(objective='binary:logistic'),
        'param':{
            'learning_rate':[0.5,0.1,0.01,0.001],
            'max_depth':[3,5,10,20],
            'n_estimators':[10,50,100,200]
        }
    }

}

# %%
score=[]
for model, mp in model_parm.items():
    model_selection=GridSearchCV(estimator=mp['model'],param_grid=mp['param'],cv=5,return_train_score=False)
    model_selection.fit(X,y)
    score.append({'model':model,
                  'model_score':model_selection.best_score_,
                  'model_parm':model_selection.best_params_
    })

# %%
score
# Out:
# [{'model': 'RandomForestClassifier',
#   'model_score': 0.9177946426586641,
#   'model_parm': {'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 'sqrt',
#    'n_estimators': 50}},
#  {'model': 'XGBClassifier',
#   'model_score': 0.9913328442814272,
#   'model_parm': {'learning_rate': 0.1, 'max_depth': 20, 'n_estimators': 200}}]

# %% [markdown]
# # Model Building

# %%
model_xgb=XGBClassifier(objective='binary:logistic',learning_rate=0.1,max_depth=20,n_estimators=20)

# %%
model_xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=20, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=20, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
model_xgb.score(X_test,y_test)
# Out:
# 0.9782222222222222

# %%
X_test[:3]
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 6723                0.65             0.96               5
# 6473                0.88             0.80               3
# 4679                0.69             0.98               3
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 6723                   226                   2              1
# 6473                   166                   2              0
# 4679                   214                   2              0
#
#       promotion_last_5years  salary
# 6723                      0       1
# 6473                      0       0
# 4679                      0       0

# %%
model_xgb.predict(X_test[:3])
# Out:
# array([0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,model_xgb.predict(X_test))
cm
# Out:
# array([[3414,   14],
#        [  84,  988]], dtype=int64)

# %%
fig=plt.figure(figsize=(15,7))
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
